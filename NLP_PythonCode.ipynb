# %%
import pandas as pd
import os
import re

def load_domain_data(data_path):
    data = []
    for domain in os.listdir(data_path):
        domain_path = os.path.join(data_path, domain)
        if os.path.isdir(domain_path):
            
            for sentiment_file in ["positive.review", "negative.review"]:
                sentiment_path = os.path.join(domain_path, sentiment_file)
                sentiment = 'Positive' if 'positive' in sentiment_file else 'Negative'
                
                if os.path.exists(sentiment_path):
                    with open(sentiment_path, 'r', encoding='utf-8', errors='ignore') as f:
                        content = f.read()
                        reviews = re.findall(r'<review_text>(.*?)</review_text>', content, re.DOTALL)
                        for review in reviews:
                            data.append({
                                'domain': domain,
                                'sentiment': sentiment,
                                'review_text': review.strip()
                            })
    return pd.DataFrame(data)

DATASET_PATH = 'sorted_data' 

df = load_domain_data(DATASET_PATH)
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

print(f"Successfully loaded {len(df)} reviews across {df['domain'].nunique()} domains.")
print("\nDataset preview:")
print(df.head())
print("\nReviews per domain:")
print(df['domain'].value_counts())
# Out:
# Successfully loaded 38548 reviews across 25 domains.
#
# Dataset preview:
#                   domain sentiment  \
# 0           gourmet_food  Positive
# 1                  video  Positive
# 2              magazines  Positive
# 3                    dvd  Negative
# 4  cell_phones_&_service  Positive
#
#                                          review_text
# 0  My mother lives in a rural part of the country...
# 1  This film is about the battle in the Ia Drang ...
# 2  Today I received the first issue - April 2006 ...
# 3  THE FRIST time i saw this movie i hated it. ho...
# 4  I agree it's a waste to get sizes you don't ne...
#
# Reviews per domain:
# domain
# video                     2000
# health_&_personal_care    2000
# dvd                       2000
# toys_&_games              2000
# apparel                   2000
# sports_&_outdoors         2000
# books                     2000
# electronics               2000
# kitchen_&_housewares      2000
# music                     2000
# camera_&_photo            1999
# magazines                 1970
# software                  1915
# baby                      1900
# beauty                    1493
# computer_&_video_games    1458
# grocery                   1352
# outdoor_living            1327
# jewelry_&_watches         1292
# gourmet_food              1208
# cell_phones_&_service     1023
# automotive                 736
# office_products            431
# musical_instruments        332
# tools_&_hardware           112
# Name: count, dtype: int64

# %%
import nltk

# %%
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Angeline
# [nltk_data]     Lewis\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer


lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def clean_text_data(text):
    """Cleans raw text for NLP models."""
    text = text.lower() 
    text = re.sub(r'<.*?>', '', text) 
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    tokens = nltk.word_tokenize(text) 
    
    # Lemmatize 
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words and len(word) > 2]
    
    return ' '.join(tokens)

print("Cleaning and preprocessing review text...")
df['cleaned_review'] = df['review_text'].apply(clean_text_data)
print("Preprocessing complete.")
print("\nPreview of original vs. cleaned text:")
print(df[['review_text', 'cleaned_review']].head())
# Out:
# Cleaning and preprocessing review text...
# Preprocessing complete.
#
# Preview of original vs. cleaned text:
#                                          review_text  \
# 0  My mother lives in a rural part of the country...
# 1  This film is about the battle in the Ia Drang ...
# 2  Today I received the first issue - April 2006 ...
# 3  THE FRIST time i saw this movie i hated it. ho...
# 4  I agree it's a waste to get sizes you don't ne...
#
#                                       cleaned_review
# 0  mother life rural part country ohio native tha...
# 1  film battle drang valley vietnam begin french ...
# 2  today received first issue april issue found a...
# 3  frist time saw movie hated however saw still g...
# 4  agree waste get size need idea public exchange...

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report


X = df['cleaned_review']
y_domain = df['domain']


X_train, X_test, y_train_domain, y_test_domain = train_test_split(
    X, y_domain, test_size=0.2, random_state=42, stratify=y_domain
)


domain_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1, 2), max_features=5000)), 
    ('clf', LogisticRegression(max_iter=1000)) 
])

print("\nTraining the Domain Classification model...")
domain_pipeline.fit(X_train, y_train_domain)
print("Training complete.")


domain_predictions = domain_pipeline.predict(X_test)
print("\n--- Domain Classification Report ---")
print("This shows how well the model predicts the product category.")
print(classification_report(y_test_domain, domain_predictions))
# Out:
# Training the Domain Classification model...
# Training complete.
#
# --- Domain Classification Report ---
# This shows how well the model predicts the product category.
#                         precision    recall  f1-score   support
#
#                apparel       0.61      0.76      0.67       400
#             automotive       0.85      0.46      0.60       147
#                   baby       0.75      0.75      0.75       380
#                 beauty       0.83      0.84      0.83       299
#                  books       0.87      0.94      0.90       400
#         camera_&_photo       0.84      0.80      0.82       400
#  cell_phones_&_service       0.83      0.63      0.72       205
# computer_&_video_games       0.87      0.83      0.85       292
#                    dvd       0.57      0.54      0.55       400
#            electronics       0.57      0.68      0.62       400
#           gourmet_food       0.67      0.63      0.65       242
#                grocery       0.69      0.70      0.70       271
# health_&_personal_care       0.52      0.53      0.52       400
#      jewelry_&_watches       0.87      0.78      0.82       258
#   kitchen_&_housewares       0.58      0.72      0.64       400
#              magazines       0.97      0.92      0.95       394
#                  music       0.88      0.89      0.89       400
#    musical_instruments       0.77      0.35      0.48        66
#        office_products       0.81      0.41      0.54        86
#         outdoor_living       0.77      0.69      0.73       265
#               software       0.83      0.86      0.85       383
#      sports_&_outdoors       0.54      0.56      0.55       400
#       tools_&_hardware       1.00      0.23      0.37        22
#           toys_&_games       0.65      0.65      0.65       400
#                  video       0.61      0.61      0.61       400
#
#               accuracy                           0.72      7710
#              macro avg       0.75      0.67      0.69      7710
#           weighted avg       0.73      0.72      0.72      7710

# %%
y_sentiment = df['sentiment']

X_train, X_test, y_train_sentiment, y_test_sentiment = train_test_split(
    X, y_sentiment, test_size=0.2, random_state=42, stratify=y_sentiment
)


sentiment_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1, 2), max_features=5000)),
    ('clf', LogisticRegression(max_iter=1000))
])

print("\nTraining the Sentiment Analysis model...")
sentiment_pipeline.fit(X_train, y_train_sentiment)
print("Training complete.")


sentiment_predictions = sentiment_pipeline.predict(X_test)
print("\n--- Sentiment Analysis Report ---")
print("This shows how well the model predicts if a review is positive or negative.")
print(classification_report(y_test_sentiment, sentiment_predictions))
# Out:
# Training the Sentiment Analysis model...
# Training complete.
#
# --- Sentiment Analysis Report ---
# This shows how well the model predicts if a review is positive or negative.
#               precision    recall  f1-score   support
#
#     Negative       0.85      0.81      0.83      3315
#     Positive       0.86      0.89      0.88      4395
#
#     accuracy                           0.86      7710
#    macro avg       0.86      0.85      0.85      7710
# weighted avg       0.86      0.86      0.86      7710

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (0.19.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.3.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.12.2)
# Requirement already satisfied: jinja2 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.6.15)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.2.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.3.1)
# Requirement already satisfied: wrapt in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jinja2->spacy) (3.0.2)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ----------------------------------- --- 11.5/12.8 MB 60.7 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 51.6 MB/s eta 0:00:00
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install jupyter ipykernel
# Out:
# Requirement already satisfied: jupyter in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (1.1.1)
# Requirement already satisfied: ipykernel in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (6.29.5)
# Requirement already satisfied: notebook in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter) (7.4.4)
# Requirement already satisfied: jupyter-console in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipywidgets in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter) (8.1.7)
# Requirement already satisfied: jupyterlab in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter) (4.4.4)
# Requirement already satisfied: comm>=0.1.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipykernel) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipykernel) (9.4.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipykernel) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipykernel) (27.0.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipykernel) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (310)
# Requirement already satisfied: six>=1.5 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.17.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets->jupyter) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets->jupyter) (3.0.15)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter) (80.9.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.24.0)
# Requirement already satisfied: requests>=2.31 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.4)
# Requirement already satisfied: idna>=2.8 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: certifi in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.26.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.5.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (4.14.1)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20250708)
# Requirement already satisfied: executing>=1.2.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\angeline lewis\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy
from spacy import displacy


nlp = spacy.load('en_core_web_sm')


print("\n--- Named Entity Recognition Examples ---")
for domain in df['domain'].unique():
    print(f"\n--- DOMAIN: {domain.upper()} ---")
    
   
    sample_review = df[df['domain'] == domain]['review_text'].iloc[0]
    doc = nlp(sample_review)
    
    print(f"Review Snippet: \"{sample_review[:200]}...\"")
    
  
    if doc.ents:
        for ent in doc.ents:
            print(f"  -> Entity: '{ent.text}', Label: '{ent.label_}' ({spacy.explain(ent.label_)})")
    else:
        print("  -> No entities found by SpaCy in this review.")
# Out:
# --- Named Entity Recognition Examples ---
#
# --- DOMAIN: GOURMET_FOOD ---
# Review Snippet: "My mother lives in a rural part of the country in Ohio (she is a native of Thailand) anyway being in a small town, it is not easy to find Thai anything, this makes it so easy to send a little taste of..."
#   -> Entity: 'Ohio', Label: 'GPE' (Countries, cities, states)
#   -> Entity: 'Thailand', Label: 'GPE' (Countries, cities, states)
#   -> Entity: 'Thai', Label: 'NORP' (Nationalities or religious or political groups)
#
# --- DOMAIN: VIDEO ---
# Review Snippet: "This film is about the battle in the Ia Drang valley in 1965 Vietnam. It begins in 1954 when a French patrol is attacked and defeated in a surprise ambush. A prophecy for the future? In one scene a wo..."
#   -> Entity: 'Ia Drang', Label: 'GPE' (Countries, cities, states)
#   -> Entity: '1965', Label: 'DATE' (Absolute or relative dates or periods)
#   -> Entity: 'Vietnam', Label: 'GPE' (Countries, cities, states)
#   -> Entity: '1954', Label: 'DATE' (Absolute or relative dates or periods)
#   -> Entity: 'French', Label: 'NORP' (Nationalities or religious or political groups)
#   -> Entity: 'one', Label: 'CARDINAL' (Numerals that do not fall under another type)
#   -> Entity: 'French', Label: 'NORP' (Nationalities or religious or political groups)
#   -> Entity: '1964', Label: 'DATE' (Absolute or relative dates or periods)
#   -> Entity: 'Sambre et Meuse', Label: 'WORK_OF_ART' (Titles of books, songs, etc.)
#   -> Entity: 'the Napoleonic Wars', Label: 'LOC' (Non-GPE locations, mountain ranges, bodies of water)
#   -> Entity: 'One', Label: 'CARDINAL' (Numerals that do not fall under another type)
#   -> Entity: 'One', Label: 'CARDINAL' (Numerals that do not fall under another type)
#   -> Entity: 'Custer', Label: 'PERSON' (People, including fictional)
#   -> Entity: 'Custer', Label: 'PERSON' (People, including fictional)
#   -> Entity: 'about 2,500', Label: 'CARDINAL' (Numerals that do not fall under another type)
#   -> Entity: 'three', Label: 'CARDINAL' (Numerals that do not fall under another type)
#   -> Entity: 'Intelligence', Label: 'ORG' (Companies, agencies, institutions, etc.)
#   -> Entity: 'Two', Label: 'CARDINAL' (Numerals that do not fall under another type)
#   -> Entity: 'the Seventh Cavalry', Label: 'ORG' (Companies, agencies, institutions, etc.)
#   -> Entity: 'Vietnamese', Label: 'NORP' (Nationalities or religious or political groups)
#   -> Entity: '1964', Label: 'DATE' (Absolute or relative dates or periods)
#   -> Entity: 'Douglas MacArthur', Label: 'PERSON' (People, including fictional)
#   -> Entity: 'LBJ', Label: 'ORG' (Companies, agencies, institutions, etc.)
#   -> Entity: 'Asia', Label: 'LOC' (Non-GPE locations, mountain ranges, bodies of water)
#   -> Entity: 'the Middle East', Label: 'LOC' (Non-GPE locations, mountain ranges, bodies of water)
#   -> Entity: 'the Revolutionary War', Label: 'EVENT' (Named hurricanes, battles, wars, sports events, etc.)
#
# --- DOMAIN: MAGAZINES ---
# Review Snippet: "Today I received the first issue - April 2006 issue. I found
# it AMAZING and INFORMATIVE resource for body, mind and
# soul practices toward healthier life..
#
# The most thing I liked about this magazine i..."
#   -> Entity: 'first', Label: 'ORDINAL' ("first", "second", etc.)
#   -> Entity: 'April 2006', Label: 'DATE' (Absolute or relative dates or periods)
#
# --- DOMAIN: DVD ---
# Review Snippet: "THE FRIST time i saw this movie i hated it. however i saw it again. it still not that great but i own a copy. its good to watch ewhen i feel sick or am stuck in the house for some other reason. howeve..."
#   -> Entity: 'FRIST', Label: 'ORG' (Companies, agencies, institutions, etc.)
#   -> Entity: 'two', Label: 'CARDINAL' (Numerals that do not fall under another type)
#
# --- DOMAIN: CELL_PHONES_&_SERVICE ---
# Review Snippet: "I agree it's a waste to get sizes you don't need. Here's an idea to do a public exchange. I do not need the large and medium, and will be glad to give to anyone, just for the postage. I just need the ..."
#   -> No entities found by SpaCy in this review.
#
# --- DOMAIN: APPAREL ---
# Review Snippet: "incorrect color was shown on the website.  it has since been added but it wasnt at the time of my purchase...."
#   -> No entities found by SpaCy in this review.
#
# --- DOMAIN: TOYS_&_GAMES ---
# Review Snippet: "i bought this thinking it was going to be really cool, but it was very boring and stupid.  it contains 3 puzzles all of which a 5 yr old can do and the games are the most stupid games ever.  the one w..."
#   -> Entity: '3', Label: 'CARDINAL' (Numerals that do not fall under another type)
#   -> Entity: '5', Label: 'CARDINAL' (Numerals that do not fall under another type)
#
# --- DOMAIN: HEALTH_&_PERSONAL_CARE ---
# Review Snippet: "I purchased this product for my husband for Christmas. He has been in two car accidents and has migraines. We thought this might help. It doesn't. He feels very uncomfortable in fact. My mom has arthr..."
#   -> Entity: 'Christmas', Label: 'DATE' (Absolute or relative dates or periods)
#   -> Entity: 'two', Label: 'CARDINAL' (Numerals that do not fall under another type)
#
# --- DOMAIN: SPORTS_&_OUTDOORS ---
# Review Snippet: "Great use for five minutes then one broke. Having use Kendo Shinai bamboo swords before I would not suggest these and only bought them as I had a $25 dollar gift certificate to get rid of..."
#   -> Entity: 'five minutes', Label: 'TIME' (Times smaller than a day)
#   -> Entity: 'Kendo Shinai', Label: 'ORG' (Companies, agencies, institutions, etc.)
#   -> Entity: '$25 dollar', Label: 'MONEY' (Monetary values, including unit)
#
# --- DOMAIN: JEWELRY_&_WATCHES ---
# Review Snippet: "Great deal and gift. If you want something different and at a good price...."
#   -> No entities found by SpaCy in this review.
#
# --- DOMAIN: MUSICAL_INSTRUMENTS ---
# Review Snippet: "they dont display all of the information.this product doesnt come with cimbols.wasnt worth what i payed for it.DONT BUY THES SET..."
#   -> No entities found by SpaCy in this review.
#
# --- DOMAIN: CAMERA_&_PHOTO ---
# Review Snippet: "this camera is a piece of junk. you have to be standing outside in bright sunlight to get a decent picture. and then when you try to use the flash it is so bright that everything in the foreground of ..."
#   -> Entity: '1', Label: 'CARDINAL' (Numerals that do not fall under another type)
#   -> Entity: 'about 10', Label: 'CARDINAL' (Numerals that do not fall under another type)
#
# --- DOMAIN: GROCERY ---
# Review Snippet: "This instant oatmeal is the only one I have had that tastes like real oatmeal.  It does not have that artificial taste that most instant oatmeals have..."
#   -> No entities found by SpaCy in this review.
#
# --- DOMAIN: BEAUTY ---
# Review Snippet: "I wasn't really thrilled with this product. It smells great but as soon as the shower is over the thrill is gone..."
#   -> No entities found by SpaCy in this review.
#
# --- DOMAIN: BABY ---
# Review Snippet: "I love the Baby Bjorn bib- it is excellent for protecting my 1 year old son's clothes as he learns to feed himself.  It is great for car rides too - I can place Cheerios in the pocket and he can feed ..."
#   -> Entity: 'Baby Bjorn', Label: 'PRODUCT' (Objects, vehicles, foods, etc. (not services))
#   -> Entity: '1 year old', Label: 'DATE' (Absolute or relative dates or periods)
#   -> Entity: 'Cheerios', Label: 'GPE' (Countries, cities, states)
#
# --- DOMAIN: KITCHEN_&_HOUSEWARES ---
# Review Snippet: "We have an Aussie/Healer mix (we think...she was a foundling) with a thick, soft coat. I've had her professionally groomed once a year for about 7 years at $60 to $75 a pop so last summer I decided to..."
#   -> Entity: 'Aussie/Healer', Label: 'ORG' (Companies, agencies, institutions, etc.)
#   -> Entity: 'about 7 years', Label: 'DATE' (Absolute or relative dates or periods)
#   -> Entity: '$60 to $75', Label: 'MONEY' (Monetary values, including unit)
#   -> Entity: 'last summer', Label: 'DATE' (Absolute or relative dates or periods)
#   -> Entity: 'all summer', Label: 'DATE' (Absolute or relative dates or periods)
#   -> Entity: 'next year', Label: 'DATE' (Absolute or relative dates or periods)
#
# --- DOMAIN: SOFTWARE ---
# Review Snippet: "I bought the Mac version of TurboTax Premier, and I installed it on my Mac with OS 10.3.9. After doing my entire return, I clicked to e-file and received a message saying, "Could not load attribute," ..."
#   -> Entity: 'Mac', Label: 'ORG' (Companies, agencies, institutions, etc.)
#   -> Entity: 'TurboTax', Label: 'ORG' (Companies, agencies, institutions, etc.)
#   -> Entity: 'Intuit', Label: 'ORG' (Companies, agencies, institutions, etc.)
#   -> Entity: 'Intuit', Label: 'ORG' (Companies, agencies, institutions, etc.)
#   -> Entity: 'Intuit', Label: 'ORG' (Companies, agencies, institutions, etc.)
#   -> Entity: 'March 26', Label: 'DATE' (Absolute or relative dates or periods)
#
# --- DOMAIN: MUSIC ---
# Review Snippet: "well i'll explain that later. she uses her own vocals. she doesn't even have the balls to let the artists who rework the song use their own vocals.I love how the editoral review uses the term "unique ..."
#   -> Entity: 'Courtney Love', Label: 'PERSON' (People, including fictional)
#   -> Entity: 'one', Label: 'CARDINAL' (Numerals that do not fall under another type)
#   -> Entity: 'about 14', Label: 'CARDINAL' (Numerals that do not fall under another type)
#   -> Entity: 'zero', Label: 'CARDINAL' (Numerals that do not fall under another type)
#
# --- DOMAIN: COMPUTER_&_VIDEO_GAMES ---
# Review Snippet: "I'm 15 and I have Star Wars: Battlefront 1 and 2, Star Wars: Knights of the Old Republic 1 and 2, this game, and I'm getting LEGO Star Wars in the mail any day now.  I really like Star Wars: Battlefro..."
#   -> Entity: '15', Label: 'DATE' (Absolute or relative dates or periods)
#   -> Entity: '1', Label: 'CARDINAL' (Numerals that do not fall under another type)
#   -> Entity: 'LEGO Star Wars', Label: 'PRODUCT' (Objects, vehicles, foods, etc. (not services))
#   -> Entity: '2 days ago', Label: 'DATE' (Absolute or relative dates or periods)
#   -> Entity: '2 PM', Label: 'TIME' (Times smaller than a day)
#   -> Entity: '1 AM', Label: 'TIME' (Times smaller than a day)
#   -> Entity: 'the next day', Label: 'DATE' (Absolute or relative dates or periods)
#   -> Entity: 'about 9 AM', Label: 'TIME' (Times smaller than a day)
#   -> Entity: 'about half a day', Label: 'DATE' (Absolute or relative dates or periods)
#   -> Entity: 'a whole minute', Label: 'TIME' (Times smaller than a day)
#   -> Entity: 'AI', Label: 'GPE' (Countries, cities, states)
#   -> Entity: 'only about 3', Label: 'CARDINAL' (Numerals that do not fall under another type)
#   -> Entity: 'only about 5', Label: 'CARDINAL' (Numerals that do not fall under another type)
#   -> Entity: 'Super Battle', Label: 'ORG' (Companies, agencies, institutions, etc.)
#   -> Entity: 'Trandoshans', Label: 'NORP' (Nationalities or religious or political groups)
#   -> Entity: 'Geonosians', Label: 'NORP' (Nationalities or religious or political groups)
#   -> Entity: 'Magna Guards', Label: 'PERSON' (People, including fictional)
#
# --- DOMAIN: BOOKS ---
# Review Snippet: "I chanced upon this book quite by accident.I am a big fan of books which inspire.This may not be a book which is high on the literary quotient, the writing does get rambling and long winded quite a nu..."
#   -> No entities found by SpaCy in this review.
#
# --- DOMAIN: OUTDOOR_LIVING ---
# Review Snippet: "These devices, tested by the FDA decades ago (including the ones with variable and intermittent pitches) do not work.  There have been a number of class-action lawsuits against the companies that sell..."
#   -> Entity: 'FDA', Label: 'ORG' (Companies, agencies, institutions, etc.)
#   -> Entity: 'decades ago', Label: 'DATE' (Absolute or relative dates or periods)
#
# --- DOMAIN: OFFICE_PRODUCTS ---
# Review Snippet: "I use fountain pens everyday, so I know what I am talking about:  This is a great fountain pen for everyday writing -- one that you will not care gets lost or damaged due to its very low price (unlike..."
#   -> Entity: 'over $100', Label: 'MONEY' (Monetary values, including unit)
#   -> Entity: 'Fantastic', Label: 'NORP' (Nationalities or religious or political groups)
#   -> Entity: 'One', Label: 'CARDINAL' (Numerals that do not fall under another type)
#   -> Entity: 'TRUE', Label: 'ORG' (Companies, agencies, institutions, etc.)
#
# --- DOMAIN: ELECTRONICS ---
# Review Snippet: "I have been enjoying these speakers outside by my pool for several months now, and the quality of the sound is excellent, particularly given the reasonable price.  I'm sure you can get better performa..."
#   -> Entity: 'several months', Label: 'DATE' (Absolute or relative dates or periods)
#   -> Entity: 'today', Label: 'DATE' (Absolute or relative dates or periods)
#
# --- DOMAIN: TOOLS_&_HARDWARE ---
# Review Snippet: "this shovel works great.I have only had the chance to use it once but it was heavy wet snow and this shovel peformed awsome.It threw snow 20-30 feet off my back porch..."
#   -> Entity: '20-30 feet', Label: 'QUANTITY' (Measurements, as of weight or distance)
#
# --- DOMAIN: AUTOMOTIVE ---
# Review Snippet: "I received 2 multi-outlet adapters for our cars, plugged them in to each car and the adapter has a red light indicator that it has a 12 volt feed.  The items I plugged in work without problem..."
#   -> Entity: '2', Label: 'CARDINAL' (Numerals that do not fall under another type)
#   -> Entity: '12', Label: 'CARDINAL' (Numerals that do not fall under another type)
